# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# __Real quick notes:__
# Importants Modules
#
# - `os`: To ‘talk’ to the OS to create, modify, delete folders and write OS-agnostic code.
# - `glob`:  to serach for files/to know what files are in a folder
# - `shutil`: To copy files

# %% [markdown]
# __The scenario:__
# You are a member of an international team analysing environmental pollution. The project involves ten cities: Cairo, Dhaka, Jakarta, Karachi, Manila, Melbourne, Osaka, Shanghai, Singapore, and Tokyo.
#
# Your task is to process and organise data from various environmental measurements. The provided zip file, `os-collaboration-exercise-data.zip`, contains all relevant data files for the past year.
#
# __Things to note__:
#
# 1. __Data Files:__ Each data file is named in the format ```month-date_city.txt``` (e.g., ```may-10_singapore.txt```).
# 1. __Data Collection:__ Data was recorded sporadically; not all days of each month have corresponding data files. The dates of data collection vary across the cities.
# 1. __Exclusion of Files:__ Ignore any non-text files, such as those in ```.pdf```, ```.png```, or ```.jpg formats```.

# %% [markdown]
# __Task 1:__
#
# - We like to convert the filename to a more useful numerical format. Specifically, we want to convert ```month-date-city.txt```. (i.e. ```may-10-singapore.txt```) to a ```mm-dd-city.txt``` (i.e. ```05-10-singapore.txt```) format.
#
# - Using the following dictionary (or otherwise), write a snippet of Python code to convert ```'oct-08_singapore.txt'``` to ```10-08-singapore.txt```.

# %%
import os
import glob
import shutil

# %%
month_number = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

# %%
#remember: spilt?
'abc'.split('b')
# Out:
# ['a', 'c']

# %%
print(month_word)
# Out:
# ['oct', '08_singapore.txt']

# %%
#Use split to split the month form the rest
month_word = 'oct-08_singapore.txt'.split('-')
month_word[0] #index the output to isolate the month

number = month_number[month_word[0]] #index the dictionary by the isolated month
almost_there_ver = f"{number}-{month_word[1]}" 

full_ver = wrong_ver.replace('_', '-')#convert the underscore in to a dash
print(full_ver)
# Out:
# 10-08-singapore.txt

# %% [markdown]
# __Task 2:__
# - Incorporate your previous code into a function named `rename_my_file(old_file_name)` that __accepts__ the __old filename__ as the argument and __returns__ the __new file name__.

# %%
def rename_my_file(old_file_name):
    month_word = old_file_name.split('-')
    month_word[0] 
    number = month_number[month_word[0]] 
    almost_there_ver = f"{number}-{month_word[1]}" 
    full_ver = almost_there_ver.replace('_', '-')
    return full_ver

# %%
rename_my_file('apr-01_melbourne.txt')
# Out:
# '04-01-melbourne.txt'

# %% [markdown]
# __Task 3:__
# - Use a `for` loop to apply the function `rename_my_file()` to the file list below.
#
# ```python
# ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
#  'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
#  'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
#  'jan-01_tokyo.txt']
# ```
# - Print out your progress in the form `old-file-name ----> new-file-name`

# %%
test_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

# %%
for name in test_list:
    new_file_name = rename_my_file(name)
    print (name + "---->" + new_file_name)
# Out:
# oct-08_singapore.txt---->10-08-singapore.txt
# jul-10_cairo.txt---->07-10-cairo.txt
# may-15_dhaka.txt---->05-15-dhaka.txt
# may-13_cairo.txt---->05-13-cairo.txt
# oct-21_cairo.txt---->10-21-cairo.txt
# jan-10_singapore.txt---->01-10-singapore.txt
# jun-20_tokyo.txt---->06-20-tokyo.txt
# aug-06_jakarta.txt---->08-06-jakarta.txt
# dec-21_karachi.txt---->12-21-karachi.txt
# jan-01_tokyo.txt---->01-01-tokyo.txt

# %% [markdown]
# __Task 4:__
# With the help of `glob`, use `rename_my_file()` to rename __all__ the `.txt` files in the folder.
#
# Note that you might have to adjust your function `rename_my_file()` to accommodate the already renamed files.

# %%
glob.glob('os-collaboration-exercise-data/**/*.txt', recursive=True)
# Out:
# ['os-collaboration-exercise-data/dec-10_osaka.txt',
#  'os-collaboration-exercise-data/jul-14_karachi.txt',
#  'os-collaboration-exercise-data/nov-17_osaka.txt',
#  'os-collaboration-exercise-data/jul-13_cairo.txt',
#  'os-collaboration-exercise-data/jun-15_manila.txt',
#  'os-collaboration-exercise-data/aug-20_tokyo.txt',
#  'os-collaboration-exercise-data/jun-16_melbourne.txt',
#  'os-collaboration-exercise-data/sep-05_tokyo.txt',
#  'os-collaboration-exercise-data/jun-22_manila.txt',
#  'os-collaboration-exercise-data/apr-11_shanghai.txt',
#  'os-collaboration-exercise-data/sep-21_singapore.txt',
#  'os-collaboration-exercise-data/feb-01_singapore.txt',
#  'os-collaboration-exercise-data/may-09_manila.txt',
#  'os-collaboration-exercise-data/jan-20_tokyo.txt',
#  'os-collaboration-exercise-data/jan-30_manila.txt',
#  'os-collaboration-exercise-data/jun-28_tokyo.txt',
#  'os-collaboration-exercise-data/apr-16_shanghai.txt',
#  'os-collaboration-exercise-data/dec-07_shanghai.txt',
# ...

# %%
for name in glob.glob('os-collaboration-exercise-data/**/*.txt', recursive=True):
    new_file_name = rename_my_file(name)
    print (name + "---->" + new_file_name) 
#Oops we need to separate it from the 'os-collaboration-exercise-data/' 
#change the backend then join it back to 'os-collaboration-exercise-data/' 
#to stitch together the whole relative path
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 2
#       1 for name in glob.glob('os-collaboration-exercise-data/**/*.txt', recursive=True):
# ----> 2     new_file_name = rename_my_file(name)
#       3     print (name + "---->" + new_file_name)
#
# Cell In[30], line 4, in rename_my_file(old_file_name)
#       2 month_word = old_file_name.split('-')
#       3 month_word[0]
# ----> 4 number = month_number[month_word[0]]
#       5 almost_there_ver = f"{number}-{month_word[1]}"
#       6 full_ver = almost_there_ver.replace('_', '-')
#
# KeyError: 'os'

# %%
'a'.join(['q', 'w', 'e'])
# Out:
# 'qawae'

# %%
#2nd try
for name in glob.glob('os-collaboration-exercise-data/**/*.txt', recursive=True):
    for_backend = name.split('/')
    backend_file_name = for_backend[1]
    new_backend_file_name = rename_my_file(backend_file_name)
    new_file_name = for_backend[0].join(new_backend_file_name) #oops this is wrong. You're joining with the whole "os-collab..." blah blah
    print (name + "---->" + new_file_name)
# Out:
# os-collaboration-exercise-data/dec-10_osaka.txt---->1os-collaboration-exercise-data2os-collaboration-exercise-data-os-collaboration-exercise-data1os-collaboration-exercise-data0os-collaboration-exercise-data-os-collaboration-exercise-dataoos-collaboration-exercise-datasos-collaboration-exercise-dataaos-collaboration-exercise-datakos-collaboration-exercise-dataaos-collaboration-exercise-data.os-collaboration-exercise-datatos-collaboration-exercise-dataxos-collaboration-exercise-datat
# ...

# %%
#3rd try

for name in glob.glob('os-collaboration-exercise-data/**/*.txt', recursive=True):
    for_backend = name.split('/')
    backend_file_name = for_backend[1]
    new_backend_file_name = rename_my_file(backend_file_name)
    new_file_name = os.path.join(for_backend[0],new_backend_file_name)
    print (name + "---->" + new_file_name)
# Out:
# os-collaboration-exercise-data/dec-10_osaka.txt---->os-collaboration-exercise-data/12-10-osaka.txt
# os-collaboration-exercise-data/jul-14_karachi.txt---->os-collaboration-exercise-data/07-14-karachi.txt
# os-collaboration-exercise-data/nov-17_osaka.txt---->os-collaboration-exercise-data/11-17-osaka.txt
# os-collaboration-exercise-data/jul-13_cairo.txt---->os-collaboration-exercise-data/07-13-cairo.txt
# os-collaboration-exercise-data/jun-15_manila.txt---->os-collaboration-exercise-data/06-15-manila.txt
# os-collaboration-exercise-data/aug-20_tokyo.txt---->os-collaboration-exercise-data/08-20-tokyo.txt
# os-collaboration-exercise-data/jun-16_melbourne.txt---->os-collaboration-exercise-data/06-16-melbourne.txt
# os-collaboration-exercise-data/sep-05_tokyo.txt---->os-collaboration-exercise-data/09-05-tokyo.txt
# os-collaboration-exercise-data/jun-22_manila.txt---->os-collaboration-exercise-data/06-22-manila.txt
# ...

# %% [markdown]
# __Task 5__:
# - Use a `for` loop to create a folder for each city.
# The list of cities is provided below for your convenience.
#
# ```python
# ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
#  'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
# ```

# %%
os.mkdir('city')

for place in ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']:
    path = os.path.join('city', place)
    os.mkdir(path)
    print(f"Created{path}")
# Out:
# Createdcity/Cairo
# Createdcity/Dhaka
# Createdcity/Jakarta
# Createdcity/Karachi
# Createdcity/Manila
# Createdcity/Melbourne
# Createdcity/Osaka
# Createdcity/Shanghai
# Createdcity/Singapore
# Createdcity/Tokyo

# %% [markdown]
# __Task 6:__
# - Use `glob` to list all the files from Cairo.
# - Now use a `for` loop and `shutil.copy()` to copy all the files related to Cairo to the corresponding folder you created.

# %%
Cairo_list = glob.glob("os*/*ro.txt") + glob.glob("os*/*ro.png") +glob.glob("os*/*ro.jpg") 
Cairo_list
# Out:
# ['os-collaboration-exercise-data/jul-13_cairo.txt',
#  'os-collaboration-exercise-data/dec-27_cairo.txt',
#  'os-collaboration-exercise-data/jul-26_cairo.txt',
#  'os-collaboration-exercise-data/may-30_cairo.txt',
#  'os-collaboration-exercise-data/jan-13_cairo.txt',
#  'os-collaboration-exercise-data/feb-26_cairo.txt',
#  'os-collaboration-exercise-data/aug-07_cairo.txt',
#  'os-collaboration-exercise-data/sep-22_cairo.txt',
#  'os-collaboration-exercise-data/jan-07_cairo.txt',
#  'os-collaboration-exercise-data/aug-26_cairo.txt',
#  'os-collaboration-exercise-data/apr-24_cairo.txt',
#  'os-collaboration-exercise-data/may-29_cairo.txt',
#  'os-collaboration-exercise-data/dec-21_cairo.txt',
#  'os-collaboration-exercise-data/sep-08_cairo.txt',
#  'os-collaboration-exercise-data/aug-18_cairo.txt',
#  'os-collaboration-exercise-data/may-17_cairo.txt',
#  'os-collaboration-exercise-data/jul-15_cairo.txt',
#  'os-collaboration-exercise-data/jun-28_cairo.txt',
# ...

# %%
city = 'Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila','Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo'

# %%
for place in ['Cairo']:
    path_to_destination = os.path.join('city', place)
    for file in Cairo_list:
        shutil.copy(file, path_to_destination)
        print(f"Done! copied files to {path_to_destination}")
# Out:
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# Done! copied files to city/Cairo
# ...

# %% [markdown]
# __Task 7:__
# - Tweak your code to move all the files to the corresponding folders of all the cities.

# %%
# list of city names with exact same syntax as the folder names
cities = ['cairo', 'dhaka', 'jakarta', 'karachi', 'manila',
 'melbourne', 'osaka', 'shanghai', 'singapore', 'tokyo']

# %%
#Loop through each city
for location in cities:
    #Find filed for the current city using glob.glob(), searches for all types of files(png, jpg and txt) with that city name
    location_list = glob.glob(f"os*/*{location}.txt") + glob.glob(f"os*/*{location}.png") +glob.glob(f"os*/*{location}.jpg") 
    #rmbr to use f strings and rmbr you can always check what you're doing halfway by printing stuff

    #construct the destination path for the current city (address to the city folder)
    path_to_destination = os.path.join('city', location)

    #loop through each file in the location_list
    for file in location_list:
        #copy each file to the new destination directory
        shutil.copy(file, path_to_destination)
        #Print a message indicating the the file has been copied (Optional)
        print(f"Done! Copied {file} to {path_to_destination}")
# Out:
# Done! Copied os-collaboration-exercise-data/jul-13_cairo.txt to city/cairo
# Done! Copied os-collaboration-exercise-data/dec-27_cairo.txt to city/cairo
# Done! Copied os-collaboration-exercise-data/jul-26_cairo.txt to city/cairo
# Done! Copied os-collaboration-exercise-data/may-30_cairo.txt to city/cairo
# Done! Copied os-collaboration-exercise-data/jan-13_cairo.txt to city/cairo
# Done! Copied os-collaboration-exercise-data/feb-26_cairo.txt to city/cairo
# Done! Copied os-collaboration-exercise-data/aug-07_cairo.txt to city/cairo
# Done! Copied os-collaboration-exercise-data/sep-22_cairo.txt to city/cairo
# Done! Copied os-collaboration-exercise-data/jan-07_cairo.txt to city/cairo
# Done! Copied os-collaboration-exercise-data/aug-26_cairo.txt to city/cairo
# Done! Copied os-collaboration-exercise-data/apr-24_cairo.txt to city/cairo
# Done! Copied os-collaboration-exercise-data/may-29_cairo.txt to city/cairo
# ...

# %% [markdown]
# Yay!![Screenshot 2024-02-22 at 2.22.23 PM.png](attachment:2e427b17-65a1-404e-9a79-267238826dfb.png)

# %% [markdown]
# ## Below is just "rough working" space (pls ignore)

# %%
# Let's write a new file for the numeric dates entirely.
# We need to have the code go through all the .txt files in the folder: Loop
# Then, we need the code to use the month_number list as a reference to change the month into its corresponding number.
# dictionary?

for key in month_number.keys():
    value=month_number[key]
    print(f"{key}_singapore.txt is {value}_singapore.txt")
# Out:
# jan_singapore.txt is 01_singapore.txt
# feb_singapore.txt is 02_singapore.txt
# mar_singapore.txt is 03_singapore.txt
# apr_singapore.txt is 04_singapore.txt
# may_singapore.txt is 05_singapore.txt
# jun_singapore.txt is 06_singapore.txt
# jul_singapore.txt is 07_singapore.txt
# aug_singapore.txt is 08_singapore.txt
# sep_singapore.txt is 09_singapore.txt
# oct_singapore.txt is 10_singapore.txt
# nov_singapore.txt is 11_singapore.txt
# dec_singapore.txt is 12_singapore.txt

# %%
'abc'.split('b')
# Out:
# ['a', 'c']

# %%
print(month_word)
# Out:
# ['oct', '08_singapore.txt']

# %%
month_word = 'oct-08_singapore.txt'.split('-')
month_word[0]
number = month_number[month_word[0]]
wrong_ver = f"{number}-{month_word[1]}"

correct_ver = wrong_ver.replace('_', '-')

# %%
# read in every file name
# extract the month name
# put file name dictionary
# put output back path 

path = 'Desktop/SPS/os-collaboration-exercise-data/'
os.path.split(path)
# Out:
# ('Desktop/SPS', 'os-collaboration-exercise-data')

# %%
month_converter(jan,'08_singapore.txt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 month_converter(jan,'08_singapore.txt')
#
# NameError: name 'jan' is not defined

# %%
def convert_fahrenheit(temperature_fahrenheit, target_scale='Celsius'):
    if target_scale == 'Kelvin':
        return (f'{temperature_fahrenheit}\u00B0F is {(temperature_fahrenheit-32)*(5/9)+273.15}K')
    return (f'{temperature_fahrenheit}\u00B0F is {(temperature_fahrenheit-32)*(5/9)}\u00B0C')

# %%
def month_converter(month, date_location):
    for item in month:
        print(f"{key}_singapore.txt is {value}_+{date_location}")
