# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# In this chapter, I will show you how to generate __high-quality, publication-ready plots__ using Python. You can readily use this knowledge in your other modules (for example, when writing reports for your experiments). There are many packages (e.g., Matplotlib, Plotty, Seaborn, Bokeh, Folium) that you can use to plot with Python. Of these, Matplotlib is the most popular and most versatile. Since some other packages are built using Matplotlib, it is usually good to know your way around __Matplotlib__ first.

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.
#
# Shown below is some code and the resulting plot.

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed') #plots the axis according to the data
plt.xlabel('x-values') #produces x-axis label
plt.ylabel('y-values') #produces y-axis label
plt.title('X vs Y') #produces title
plt.grid(alpha=.25) #produces gridlines
plt.legend(loc='upper left') #produces a legen in the upper left corner of plot

# %% [markdown]
# Copy, paste, and run this code snippet to generate the plot. Then, spend a few minutes perusing the code to figure out what each line achieves in the plot.
#
# A simple way to do this is by commenting out some lines to turn off their contributions or changing some parameters (e.g., `loc` to `bottom left`) and numbers (e.g., `alpha` to `.8`). It will help you learn faster if you try to predict what will happen before running the code.

# %% [markdown]
# ### Things to note

# %% [markdown]
# You can use the following abbreviations if you like:
# | Long form | Abbreviation |
# |:---------:|:------------:|
# |   `color`   |       `c`      |
# | `linestyle` |      `ls`      |
# | `linewidth` |      `lw`      |
#
# so, both the following lines produce the same result:

# %%
# You can plot with the full length terms:
plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=2, label='Y values')

plt.xlabel('x-values') 
plt.ylabel('y-values') 
plt.title('X vs Y')
plt.grid(alpha=.25) 
plt.legend(loc='upper left')

# %%
# Or, the same can be achieved with abbreviated forms c, ls & lw
plt.plot(x, y_1, c='red', ls='dashed', lw=2, label='Y values')

plt.xlabel('x-values') 
plt.ylabel('y-values') 
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# 2. Jupyter is an interactive environment, so you will see an output even if you omit `plt.show()`. However, __it is good practice to include this line anyway so your code will also work in non-interactive environments (i.e. the command line)__ (for instance, when the script is run directly from the command line).
# 2. The plotting functions usually have default values for the styling parameters. So, if you wish, you can keep it simple and plot just using:

# %%
plt.plot(x, y_1, y_2, label='X vs Y')

plt.xlabel('x-values') 
plt.ylabel('y-values') 
plt.title('X vs Y')
plt.grid(alpha=.25)

# %% [markdown]
# The resulting plot is shown alongside.
#
# 4. You can __split the arguments into separate lines__ to improve readability.
# So, both of the following forms are also acceptable:

# %%
# The arguments in a single line 
plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=2)

plt.xlabel('x-values') 
plt.ylabel('y-values') 
plt.title('X vs Y')
plt.grid(alpha=.25)

# %%
# arguments split in to separate lines for better readability also works
plt.plot(x, y_1, label='Y values',
           color='red', linestyle='dashed')

plt.xlabel('x-values') 
plt.ylabel('y-values') 
plt.title('X vs Y')
plt.grid(alpha=.25)

# %% [markdown]
# 5. The __order__ of how you specify the __keyword arguments__ (`color`, `linewidth`, …) __does not matter__.

# %%
#Order of the key arguments does not matter. See if we shuffle, we still get the same result:
plt.plot(x, y_1, 
         linestyle='dashed', color='red', label='Y values')

plt.xlabel('x-values') 
plt.ylabel('y-values') 
plt.title('X vs Y')
plt.grid(alpha=.25)

# %% [markdown]
# ## 1.2 Adding another plot

# %% [markdown]
# You can __add another `plot`__ command to the graph to plot the data of __y_2__ in blue by adding the following line.

# %%
# Simply add another plt.plot line of code to graph another line
plt.plot(x, y_1, 
         linestyle='dashed', color='red', label='Y1 values')
plt.plot(x, y_2,
         label='Y2 values', color='blue')

plt.xlabel('x-values') 
plt.ylabel('y-values') 
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## 1.3 Yet another plot but with error bars
#
# Let me add another plot, but this time I will also include
#  and
#  error bars for the points. The plotting command I need to use for this is called `errorbar()`.
#
#  ```python
# plt.errorbar(x, y_3,
#              xerr=x_error, yerr=y_error,
#              label="Y3 with errors",
#              color="green")
# ```

# %%
# Altogether, it'll look like this:

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# In this example, I have provided __constant errors__ for all the points. However, you __can also provide a list of errors__ so that each will have a different length.

# %% [markdown]
# __Note:__ From here onwards, I will show a minimum of code related to styling to reduce clutter. You should, however, still retain them to get nice-looking plots.

# %% [markdown]
# # 2 Better with NumPy
#
# Often, it is easier to use NumPy arrays instead of Python lists. So, let’s first convert the Python lists into NumPy arrays and then redo the plot in the previous step.

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

import numpy as np

# convert the python lists into numpy arrays
np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')

plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## 2.1 Adding mathematical functions
# Now we get to why using numpy arrays are better!
# So, one of the __advantages of NumPy arrays__ is that __they allow us to generate data-related mathematical functions easily__. Let’s reuse our previous code to plot
# $x^2$ and $sin(x)$

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # The math stuff
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')           


plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# Ah but alas, our plot does not look good because
# $sin(x)$ lies between $\pm1$, but $x^2$
#  has no such bounds. One way to fix this is to add another y-axis that shares the same x-axis.

# %% [markdown]
# ## We need another axis!

# %% [markdown]
# Matplotlib offers a variety of ways to have multiple axes. The simplest way is to __have another y-axis__ that shares the same x-axis. We can _use the command `twinx()` for this._

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2

plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ### Things to note
#
# - We now have two `legend()` calls, one for each axis.
#
# - our plot still does not look good because we have only a few points. Let’s use `np.linspace()` to fix this with:

# %%
#Use np.linespace rather than x = np.array([0, 1, 2, 3, 4, 5, 6]) which plots makes 6 points

x = np.linspace(0, 6, 100) # specifices to create 100 equally spaced points between 0 and 6. 
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2

plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# # 3 Saving to disc

# %% [markdown]
# If you want to use your plot in a report or presentation, you must first __save it to disk__. Luckily, Matplotlib makes it astonishingly easy to export plots into many formats (PDF, JPEG, PNG, BMP, etc.) and at different resolutions.
#
# - We need to use the function `savefig()` for this.
# - We specify the format with the extension (e.g., filename.pdf) of the file name,
# - We specify resolution by use dots-per-inch (`dpi`).

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, sin_x,
         label='sin x', color='blue')
plt.legend(loc='lower right')

plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

plt.savefig('simple-plot.png', dpi=150)
#Rmbr to place your plt.savefig() on the very last line so 
#you're saving all aspects of your plot

# %% [markdown]
# That’s all! Yes, it’s that easy!
#
# When you run this code, you will find the file saved in the same directory (folder) as the one in your notebook lives in. If you want it saved elsewhere, specify the path in more detail. For example:
#
# - Windows `plt.savefig('C://Desktop/simple-plot.png', dpi=150)`
# - macOS `plt.savefig('~/Desktop/simple-plot.png', dpi=150)`

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files
#
# Plotting data stored in a file (e.g., spreadsheet, text file, database) is a routine task for a scientist. In fact, the first thing you should do with any data is to look at it with a simple plot.
#
# For the rest of this section, I will use the Earth’s land temperature data from the Berkeley Earth website. Please visit the site (Global Warming
#  Data Overview) and download the average temperature data for Daily Land. The original name of the file should be `Complete_TAVG_daily.txt`
#
# It looks like this:

# %% [markdown]
# ![Screenshot 2024-02-23 at 11.11.47 AM.png](attachment:c8797a52-483b-4229-aab2-041f54e41abe.png)

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)

# Load data from the file 'Complete_TAVG_daily.txt', skipping the first 24 rows
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

# Extract date and anomaly columns from the loaded data
date = data[:, 0]       # Since date column is the first column
anomaly = data[:, -1]   # reverese indexing since the anomaly column is the last column

# Plot date against anomaly
plt.plot(date, anomaly, alpha=0.5)  # Alpha parameter controls transparency of the plot

plt.ylim([-8, 8]) # Set y-axis limits
plt.xlabel('Year') # Label x-axis

plt.ylabel('Temperature ($^\circ$C)') # Label y-axis
plt.title('Global Average Daily Temperature') # Set plot title
plt.grid(alpha=0.25) # Display gridlines with specified transparency

# %% [markdown]
# I have used a _small alpha value to soften the colour_ of the plot and made the plot range symmetrical in the
# $y$ direction.
#
# Let’s now add a horizontal line at the zero value to highlight the trend shown by the data.
# The `hlines()` function needs a
# $y$-value and starting and ending values for $x$

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)

# Load data from the file 'Complete_TAVG_daily.txt', skipping the first 24 rows
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

# Extract date and anomaly columns from the loaded data
date = data[:, 0]       # Since date column is the first column
anomaly = data[:, -1]   # reverese indexing since the anomaly column is the last column

# Plot date against anomaly
plt.plot(date, anomaly, alpha=0.5)  # Alpha parameter controls transparency of the plot

plt.ylim([-8, 8]) # Set y-axis limits
plt.xlabel('Year') # Label x-axis

plt.ylabel('Temperature ($^\circ$C)') # Label y-axis
plt.title('Global Average Daily Temperature') # Set plot title
plt.grid(alpha=0.25) # Display gridlines with specified transparency 
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey') # adds horizontal line

# %% [markdown]
# ## 4.2 Styles
#
# Many want a decent-looking plot without spending time customising it. To facilitate this __Matplotlib offers some standard style templates__ (see here). I am going to use the one called _fivethirtyeight_.
#
# - This line must be included right at the top!
# ```python
# plt.style.use('fivethirtyeight')
# ```
#
# Et voila! Do you see global warming?!

# %%
#Here is the complete code for the final product:

#Using the standard Matplotlib style 'fivethirtyeight'
plt.style.use('fivethirtyeight')

data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)

# Load data from the file 'Complete_TAVG_daily.txt', skipping the first 24 rows
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

# Extract date and anomaly columns from the loaded data
date = data[:, 0]       # Since date column is the first column
anomaly = data[:, -1]   # reverese indexing since the anomaly column is the last column

# Plot date against anomaly
plt.plot(date, anomaly, alpha=0.5)  # Alpha parameter controls transparency of the plot

plt.ylim([-8, 8]) # Set y-axis limits
plt.xlabel('Year') # Label x-axis

plt.ylabel('Temperature ($^\circ$C)') # Label y-axis
plt.title('Global Average Daily Temperature') # Set plot title
plt.grid(alpha=0.25) # Display gridlines with specified transparency 
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey') # adds horizontal line

# %% [markdown]
# ### xkcd! style

# %% [markdown]
# Okay, since we are talking about styles, I must tell you that the developers of Matplotlib have a healthy sense of humour and have included the __option of making your plots in the xkcd style__.
#
# To enable this, just run plt.xkcd() instead of setting a style. Here is what the previous plot looks like using the xkcd style. Cool!

# %%
# Using the xkcd style
with plt.xkcd()

# Load data from the file 'Complete_TAVG_daily.txt', skipping the first 24 rows
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

# Extract date and anomaly columns from the loaded data
date = data[:, 0]       # Since date column is the first column
anomaly = data[:, -1]   # reverese indexing since the anomaly column is the last column

# Plot date against anomaly
plt.plot(date, anomaly, alpha=0.5)  # Alpha parameter controls transparency of the plot

plt.ylim([-8, 8]) # Set y-axis limits
plt.xlabel('Year') # Label x-axis

plt.ylabel('Temperature ($^\circ$C)') # Label y-axis
plt.title('Global Average Daily Temperature') # Set plot title
plt.grid(alpha=0.25) # Display gridlines with specified transparency 
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey') # adds horizontal line
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...

# %% [markdown]
# Hi Yuan Zhe, seems like I don;t have the font family necessary for the xkcd style? How can I overcome this?

# %% [markdown]
# ### Resetting styles
#
# If you want to reset things and jump out of this style, you need to set the default style using:
# ```python
# plt.style.use('default')
# ```

# %%
# Returning to using the default Matplotlib style 
plt.style.use('default')

data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)

# Load data from the file 'Complete_TAVG_daily.txt', skipping the first 24 rows
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)

# Extract date and anomaly columns from the loaded data
date = data[:, 0]       # Since date column is the first column
anomaly = data[:, -1]   # reverese indexing since the anomaly column is the last column

# Plot date against anomaly
plt.plot(date, anomaly, alpha=0.5)  # Alpha parameter controls transparency of the plot

plt.ylim([-8, 8]) # Set y-axis limits
plt.xlabel('Year') # Label x-axis

plt.ylabel('Temperature ($^\circ$C)') # Label y-axis
plt.title('Global Average Daily Temperature') # Set plot title
plt.grid(alpha=0.25) # Display gridlines with specified transparency 
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey') # adds horizontal line
